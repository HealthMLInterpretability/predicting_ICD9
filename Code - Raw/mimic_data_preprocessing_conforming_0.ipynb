# %% [markdown]
# ## Importing and Data Exploration {-}

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
noteevents_df = pd.read_csv('/Users/JoKerry/Desktop/CSML1030 - Machine Learning Capstone/NOTEEVENTS_WITH_AGE.csv')
noteevents_df
# Out:
# /Applications/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (4,5) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#           ROW_ID  SUBJECT_ID   HADM_ID   CHARTDATE            CHARTTIME  \
# 0            174       22532  167853.0  2151-08-04                  NaN
# 1            175       13702  107527.0  2118-06-14                  NaN
# 2            176       13702  167118.0  2119-05-25                  NaN
# 3            177       13702  196489.0  2124-08-18                  NaN
# 4            178       26880  135453.0  2162-03-25                  NaN
# ...          ...         ...       ...         ...                  ...
# 2083175  2070657       31097  115637.0  2132-01-21  2132-01-21 03:27:00
# 2083176  2070658       31097  115637.0  2132-01-21  2132-01-21 09:50:00
# ...

# %%
noteevents_df[noteevents_df['AGE'] ==0]
# Out:
#           ROW_ID  SUBJECT_ID   HADM_ID   CHARTDATE            CHARTTIME  \
# 0            174       22532  167853.0  2151-08-04                  NaN
# 8            182       56174  163469.0  2118-08-12                  NaN
# 26           237       26601  155131.0  2131-12-29                  NaN
# 29           240       27051  113012.0  2194-02-02                  NaN
# 60           207        5239  129387.0  2189-02-26                  NaN
# ...          ...         ...       ...         ...                  ...
# 2083175  2070657       31097  115637.0  2132-01-21  2132-01-21 03:27:00
# 2083176  2070658       31097  115637.0  2132-01-21  2132-01-21 09:50:00
# 2083177  2070659       31097  115637.0  2132-01-21  2132-01-21 16:42:00
# 2083178  2070660       31097  115637.0  2132-01-21  2132-01-21 18:05:00
# 2083179  2070661       31097  115637.0  2132-01-21  2132-01-21 18:05:00
#
#                    STORETIME           CATEGORY DESCRIPTION     CGID  ISERROR  \
# ...

# %%
# noteevents_df_test.TEXT[1441577]

# %%
# admission_df_test = admission_df[admission_df['HADM_ID'] == 170407.0]
# admission_df_test

# %%
# noteevents_df_test = noteevents_df[noteevents_df['HADM_ID'] == 107527.0]
# noteevents_df_test

# %%
sns.kdeplot(data=noteevents_df, x='SUBJECT_ID')
# Out:
# <AxesSubplot:xlabel='SUBJECT_ID', ylabel='Density'>

# %%
noteevents_df['HADM_ID'].isnull().sum()
# Out:
# 231836

# %%
noteevents_df['HADM_ID'].nunique()
# Out:
# 58361

# %%
admission_df = pd.read_csv('/Users/JoKerry/Desktop/CSML1030 - Machine Learning Capstone/mimic-iii-clinical-database-1.4/ADMISSIONS.csv')
admission_df
# Out:
#        ROW_ID  SUBJECT_ID  HADM_ID            ADMITTIME            DISCHTIME  \
# 0          21          22   165315  2196-04-09 12:26:00  2196-04-10 15:54:00
# 1          22          23   152223  2153-09-03 07:15:00  2153-09-08 19:10:00
# 2          23          23   124321  2157-10-18 19:34:00  2157-10-25 14:00:00
# 3          24          24   161859  2139-06-06 16:14:00  2139-06-09 12:48:00
# 4          25          25   129635  2160-11-02 02:06:00  2160-11-05 14:55:00
# ...       ...         ...      ...                  ...                  ...
# 58971   58594       98800   191113  2131-03-30 21:13:00  2131-04-02 15:02:00
# 58972   58595       98802   101071  2151-03-05 20:00:00  2151-03-06 09:10:00
# 58973   58596       98805   122631  2200-09-12 07:15:00  2200-09-20 12:08:00
# 58974   58597       98813   170407  2128-11-11 02:29:00  2128-12-22 13:11:00
# 58975   58598       98813   190264  2131-10-25 03:09:00  2131-10-26 17:44:00
#
# ...

# %%
admission_df['SUBJECT_ID'].nunique()
# Out:
# 46520

# %%
admission_df['SUBJECT_ID'].isnull().sum()
# Out:
# 0

# %%
admission_df['HADM_ID'].nunique()
# Out:
# 58976

# %%
admission_df['HADM_ID'].isnull().sum()
# Out:
# 0

# %%
admission_df['ADMISSION_TYPE'].value_counts()
# Out:
# EMERGENCY    42071
# NEWBORN       7863
# ELECTIVE      7706
# URGENT        1336
# Name: ADMISSION_TYPE, dtype: int64

# %%
# removing NEWBORN types
admission_df_cleaned = admission_df.loc[admission_df.ADMISSION_TYPE != 'NEWBORN'].copy()
admission_df_cleaned
# Out:
#        ROW_ID  SUBJECT_ID  HADM_ID            ADMITTIME            DISCHTIME  \
# 0          21          22   165315  2196-04-09 12:26:00  2196-04-10 15:54:00
# 1          22          23   152223  2153-09-03 07:15:00  2153-09-08 19:10:00
# 2          23          23   124321  2157-10-18 19:34:00  2157-10-25 14:00:00
# 3          24          24   161859  2139-06-06 16:14:00  2139-06-09 12:48:00
# 4          25          25   129635  2160-11-02 02:06:00  2160-11-05 14:55:00
# ...       ...         ...      ...                  ...                  ...
# 58971   58594       98800   191113  2131-03-30 21:13:00  2131-04-02 15:02:00
# 58972   58595       98802   101071  2151-03-05 20:00:00  2151-03-06 09:10:00
# 58973   58596       98805   122631  2200-09-12 07:15:00  2200-09-20 12:08:00
# 58974   58597       98813   170407  2128-11-11 02:29:00  2128-12-22 13:11:00
# 58975   58598       98813   190264  2131-10-25 03:09:00  2131-10-26 17:44:00
#
# ...

# %%
admission_df_cleaned['HADM_ID'].nunique()
# Out:
# 51113

# %%
admission_df_cleaned['SUBJECT_ID'].nunique()
# Out:
# 38888

# %%
sns.kdeplot(data=noteevents_df, x='SUBJECT_ID')
# Out:
# <AxesSubplot:xlabel='SUBJECT_ID', ylabel='Density'>

# %%
sns.kdeplot(data=admission_df_cleaned, x='SUBJECT_ID')
# Out:
# <AxesSubplot:xlabel='SUBJECT_ID', ylabel='Density'>

# %%
sns.kdeplot(data=noteevents_df, x='HADM_ID')
# Out:
# <AxesSubplot:xlabel='HADM_ID', ylabel='Density'>

# %%
sns.kdeplot(data=admission_df_cleaned, x='HADM_ID')
# Out:
# <AxesSubplot:xlabel='HADM_ID', ylabel='Density'>

# %% [markdown]
# ## Loading Noteevents DataFrame with Labels {-}

# %%
mimic_text_labels_merge = pd.read_csv('/Users/JoKerry/Desktop/CSML1030 - Machine Learning Capstone/mimic_admissions_and_discharge/1 Data Preprocessing/mimic_text_label_merge.csv')
mimic_text_labels_merge
# Out:
#        ROW_ID_x  SUBJECT_ID_x   HADM_ID  SEQ_NUM  ICD9_CODE  \
# 0        269651         24136  153714.0      1.0       5849
# 1        341281         29799  165367.0      1.0      51881
# 2        484212         62854  129565.0      1.0      51881
# 3        339195         29631  141170.0      1.0      51881
# 4        157832         14106  184643.0      1.0       5849
# ...         ...           ...       ...      ...        ...
# 32046    278595         24955  154989.0     32.0      53081
# 32047    496889         65659  133827.0     32.0      53081
# 32048    504720         67348  179548.0     32.0       4019
# 32049    549697         77282  129551.0     36.0       4019
# 32050    465900         58773  170349.0     39.0      53081
#
#                  CHARTTIME            STORETIME           CATEGORY     CGID  \
# 0                      NaN                  NaN  Discharge summary      NaN
# 1      2200-08-05 15:44:00  2200-08-05 16:13:00      Nursing/other  20848.0
# ...

# %% [markdown]
# ## Using Merging on Noteevents Labels and Admissions {-}

# %%
mimic_text_labels_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32051 entries, 0 to 32050
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ROW_ID_x      32051 non-null  int64
#  1   SUBJECT_ID_x  32051 non-null  int64
#  2   HADM_ID       32051 non-null  float64
#  3   SEQ_NUM       32051 non-null  float64
#  4   ICD9_CODE     32051 non-null  int64
#  5   CHARTTIME     19789 non-null  object
#  6   STORETIME     12006 non-null  object
#  7   CATEGORY      32051 non-null  object
#  8   CGID          12006 non-null  float64
#  9   ISERROR       7 non-null      float64
#  10  TEXT          32051 non-null  object
#  11  AGE           32051 non-null  int64
# dtypes: float64(4), int64(4), object(4)
# memory usage: 2.9+ MB

# %%
admission_df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51113 entries, 0 to 58975
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ROW_ID                51113 non-null  int64
#  1   SUBJECT_ID            51113 non-null  int64
#  2   HADM_ID               51113 non-null  int64
#  3   ADMITTIME             51113 non-null  object
#  4   DISCHTIME             51113 non-null  object
#  5   DEATHTIME             5792 non-null   object
#  6   ADMISSION_TYPE        51113 non-null  object
#  7   ADMISSION_LOCATION    51113 non-null  object
#  8   DISCHARGE_LOCATION    51113 non-null  object
#  9   INSURANCE             51113 non-null  object
#  10  LANGUAGE              33358 non-null  object
#  11  RELIGION              50662 non-null  object
#  12  MARITAL_STATUS        48539 non-null  object
#  13  ETHNICITY             51113 non-null  object
#  14  EDREGTIME             30877 non-null  object
# ...

# %%
df = mimic_text_labels_merge.merge(admission_df_cleaned, on='HADM_ID')
df
# Out:
#        ROW_ID_x  SUBJECT_ID_x   HADM_ID  SEQ_NUM  ICD9_CODE  \
# 0        269651         24136  153714.0      1.0       5849
# 1        341281         29799  165367.0      1.0      51881
# 2        484212         62854  129565.0      1.0      51881
# 3        339195         29631  141170.0      1.0      51881
# 4        157832         14106  184643.0      1.0       5849
# ...         ...           ...       ...      ...        ...
# 31972    278595         24955  154989.0     32.0      53081
# 31973    496889         65659  133827.0     32.0      53081
# 31974    504720         67348  179548.0     32.0       4019
# 31975    549697         77282  129551.0     36.0       4019
# 31976    465900         58773  170349.0     39.0      53081
#
#                  CHARTTIME            STORETIME           CATEGORY     CGID  \
# 0                      NaN                  NaN  Discharge summary      NaN
# 1      2200-08-05 15:44:00  2200-08-05 16:13:00      Nursing/other  20848.0
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
df
# Out:
#        ROW_ID_x  SUBJECT_ID_x   HADM_ID  SEQ_NUM  ICD9_CODE  \
# 0        269651         24136  153714.0      1.0       5849
# 1        341281         29799  165367.0      1.0      51881
# 2        484212         62854  129565.0      1.0      51881
# 3        339195         29631  141170.0      1.0      51881
# 4        157832         14106  184643.0      1.0       5849
# ...         ...           ...       ...      ...        ...
# 31972    278595         24955  154989.0     32.0      53081
# 31973    496889         65659  133827.0     32.0      53081
# 31974    504720         67348  179548.0     32.0       4019
# 31975    549697         77282  129551.0     36.0       4019
# 31976    465900         58773  170349.0     39.0      53081
#
#                  CHARTTIME            STORETIME           CATEGORY     CGID  \
# 0                      NaN                  NaN  Discharge summary      NaN
# 1      2200-08-05 15:44:00  2200-08-05 16:13:00      Nursing/other  20848.0
# ...

# %%
df['HADM_ID'].nunique()
# Out:
# 31977

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31977 entries, 0 to 31976
# Data columns (total 30 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ROW_ID_x              31977 non-null  int64
#  1   SUBJECT_ID_x          31977 non-null  int64
#  2   HADM_ID               31977 non-null  float64
#  3   SEQ_NUM               31977 non-null  float64
#  4   ICD9_CODE             31977 non-null  int64
#  5   CHARTTIME             19724 non-null  object
#  6   STORETIME             11947 non-null  object
#  7   CATEGORY              31977 non-null  object
#  8   CGID                  11947 non-null  float64
#  9   ISERROR               7 non-null      float64
#  10  TEXT                  31977 non-null  object
#  11  AGE                   31977 non-null  int64
#  12  ROW_ID                31977 non-null  int64
#  13  SUBJECT_ID            31977 non-null  int64
#  14  ADMITTIME             31977 non-null  object
# ...

# %%
df_over_90 = df[df['AGE']>90]
df_over_90
# Out:
#        ROW_ID_x  SUBJECT_ID_x   HADM_ID  SEQ_NUM  ICD9_CODE  \
# 1757     643849         98417  127156.0      2.0       5849
# 2051     508238         68128  189927.0      2.0       5849
# 2292     418544         48812  157663.0      2.0       5849
# 3958      58206          5196  106963.0      2.0      51881
# 4944     208896         18768  132275.0      2.0      51881
# 5664     532504         73565  106883.0      2.0       5849
# 6168     611351         91343  131485.0      2.0      51881
# 10043    471566         59903  110458.0      3.0       5849
# 10071    418557         48812  190481.0      3.0       5849
# 11304    357599         31082  105967.0      3.0       4019
# 12361    605355         90051  160024.0      4.0       5849
# 17055    313258         27738  147070.0      5.0       4019
# 19013    538882         75047  180866.0      6.0       4019
# 22427    514786         69375  175452.0      7.0       4019
# 24019    615154         92135  134027.0      7.0      53081
# ...

# %%
print(df.TEXT[5664])
# Out:
# HPI:  Pt was at her church today when she started acting confused,
#    speaking non-sensically, and c/o abd pain.  She was brought to [**Hospital1 1**] ED
#    by her church friends where she was found to be febrile to 102 F oral
#    and Hotn to 70's systolic.  Pt was intubated for airway protection,
#    fluid resuscitated, started on vasopressors for BP support and sent to
#    MICU for further mgt.
#    Tests / Cultures:
#    CT scan:  head, chest, abd, pelvis > neg
#    MRI:  head > neg
#    US:  liver / GB, cardiac > neg
#    Films:  CXR, tib / fib > neg
#    Blood cx > [**12-20**] GPC in chains (Strep B)
#    HSV > pending
#    Leptospirosis serology > pending
#    Transvaginal Ultrasound =pending
#    Access:  Right and left peripheral 20 and 18 gauge
#    Code Status:  Full               Allergy: Tetracycline > rash
#    Sepsis without organ dysfunction
#    Assessment:
#    Action:
#    Response:
#    Plan:
#    Pain control (acute pain, chronic pain)
#    Assessment:
# ...

# %% [markdown]
# ## Converting AGE to Specific Values {-}

# %%
my_list = [1757, 3958, 5664, 10071, 11304, 12361, 17055, 19013, 30560]

# %%
df.loc[my_list, 'AGE'] = 0
df
# Out:
#        ROW_ID_x  SUBJECT_ID_x   HADM_ID  SEQ_NUM  ICD9_CODE  \
# 0        269651         24136  153714.0      1.0       5849
# 1        341281         29799  165367.0      1.0      51881
# 2        484212         62854  129565.0      1.0      51881
# 3        339195         29631  141170.0      1.0      51881
# 4        157832         14106  184643.0      1.0       5849
# ...         ...           ...       ...      ...        ...
# 31972    278595         24955  154989.0     32.0      53081
# 31973    496889         65659  133827.0     32.0      53081
# 31974    504720         67348  179548.0     32.0       4019
# 31975    549697         77282  129551.0     36.0       4019
# 31976    465900         58773  170349.0     39.0      53081
#
#                  CHARTTIME            STORETIME           CATEGORY     CGID  \
# 0                      NaN                  NaN  Discharge summary      NaN
# 1      2200-08-05 15:44:00  2200-08-05 16:13:00      Nursing/other  20848.0
# ...

# %%
df.AGE[3958]
# Out:
# 0

# %%
dictionary = {2051:86,
            2397:32,
            4944:68,
            6168:85}

# %%
df.loc[2051, 'AGE'] = 86
df.loc[2397, 'AGE'] = 32
df.loc[4944, 'AGE'] = 68
df.loc[6168, 'AGE'] = 85

# %%
df.AGE[6168]
# Out:
# 85

# %%
df.loc[[6168]]
# Out:
#       ROW_ID_x  SUBJECT_ID_x   HADM_ID  SEQ_NUM  ICD9_CODE  \
# 6168    611351         91343  131485.0      2.0      51881
#
#                 CHARTTIME STORETIME   CATEGORY  CGID  ISERROR  \
# 6168  2159-01-17 10:48:00       NaN  Radiology   NaN      NaN
#
#                                                    TEXT  AGE  ROW_ID  \
# 6168  [**2159-1-17**] 10:48 AM\n CHEST (PORTABLE AP)...   85   56190
#
#       SUBJECT_ID            ADMITTIME            DISCHTIME  \
# 6168       91343  2159-01-09 21:16:00  2159-01-25 03:34:00
#
#                 DEATHTIME ADMISSION_TYPE         ADMISSION_LOCATION  \
# 6168  2159-01-25 03:34:00       ELECTIVE  PHYS REFERRAL/NORMAL DELI
#
#      DISCHARGE_LOCATION INSURANCE LANGUAGE  RELIGION MARITAL_STATUS ETHNICITY  \
# 6168       DEAD/EXPIRED  Medicare     ENGL  CATHOLIC        MARRIED     WHITE
#
#      EDREGTIME EDOUTTIME                                          DIAGNOSIS  \
# ...

# %%
df[df['AGE']==0]
# Out:
#        ROW_ID_x  SUBJECT_ID_x   HADM_ID  SEQ_NUM  ICD9_CODE  \
# 1        341281         29799  165367.0      1.0      51881
# 3        339195         29631  141170.0      1.0      51881
# 5          8272           720  100753.0      1.0      51881
# 16       157919         14114  183312.0      1.0      51881
# 20       187471         16832  149054.0      1.0       5849
# ...         ...           ...       ...      ...        ...
# 31969    296675         26492  125102.0     31.0       4019
# 31970    603140         89565  178705.0     31.0      53081
# 31971    307987         27374  169788.0     31.0      53081
# 31972    278595         24955  154989.0     32.0      53081
# 31976    465900         58773  170349.0     39.0      53081
#
#                  CHARTTIME            STORETIME       CATEGORY     CGID  \
# 1      2200-08-05 15:44:00  2200-08-05 16:13:00  Nursing/other  20848.0
# 3      2180-12-06 02:46:00  2180-12-06 02:52:32        Nursing  14757.0
# ...

# %%
#df.to_csv('mimic_all_ages', index=False)

# %% [markdown]
# ## Conforming AGE Zeros to SUBJECT_ID Norm {-}

# %%
df[df['AGE']==0]
# Out:
#        ROW_ID_x  SUBJECT_ID_x   HADM_ID  SEQ_NUM  ICD9_CODE  \
# 1        341281         29799  165367.0      1.0      51881
# 3        339195         29631  141170.0      1.0      51881
# 5          8272           720  100753.0      1.0      51881
# 16       157919         14114  183312.0      1.0      51881
# 20       187471         16832  149054.0      1.0       5849
# ...         ...           ...       ...      ...        ...
# 31969    296675         26492  125102.0     31.0       4019
# 31970    603140         89565  178705.0     31.0      53081
# 31971    307987         27374  169788.0     31.0      53081
# 31972    278595         24955  154989.0     32.0      53081
# 31976    465900         58773  170349.0     39.0      53081
#
#                  CHARTTIME            STORETIME       CATEGORY     CGID  \
# 1      2200-08-05 15:44:00  2200-08-05 16:13:00  Nursing/other  20848.0
# 3      2180-12-06 02:46:00  2180-12-06 02:52:32        Nursing  14757.0
# ...

# %%
df['SUBJECT_ID'].nunique()
# Out:
# 25722

# %%
#df.duplicated(subset=['SUBJECT_ID']).value_counts()

# %%
#df1 = df[df['SUBJECT_ID'].duplicated() == True]

# %%
#df1[df1['SUBJECT_ID']==23]

# %%
#df1.sort_values('SUBJECT_ID')

# %%
# df1 = df['SUBJECT_ID']

# df_sorted = df[df1.isin(df1[df1.duplicated()])].sort_values('SUBJECT_ID')
# df_sorted

# %%
# df_sorted['SUBJECT_ID'].nunique()

# %%
# df_sorted[df_sorted['AGE']==0]

# %%
# print(df_sorted.TEXT[14610])

# %%
# df_sorted[df_sorted['AGE']>100]

# %%
df
# Out:
#        ROW_ID_x  SUBJECT_ID_x   HADM_ID  SEQ_NUM  ICD9_CODE  \
# 0        269651         24136  153714.0      1.0       5849
# 1        341281         29799  165367.0      1.0      51881
# 2        484212         62854  129565.0      1.0      51881
# 3        339195         29631  141170.0      1.0      51881
# 4        157832         14106  184643.0      1.0       5849
# ...         ...           ...       ...      ...        ...
# 31972    278595         24955  154989.0     32.0      53081
# 31973    496889         65659  133827.0     32.0      53081
# 31974    504720         67348  179548.0     32.0       4019
# 31975    549697         77282  129551.0     36.0       4019
# 31976    465900         58773  170349.0     39.0      53081
#
#                  CHARTTIME            STORETIME           CATEGORY     CGID  \
# 0                      NaN                  NaN  Discharge summary      NaN
# 1      2200-08-05 15:44:00  2200-08-05 16:13:00      Nursing/other  20848.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31977 entries, 0 to 31976
# Data columns (total 30 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ROW_ID_x              31977 non-null  int64
#  1   SUBJECT_ID_x          31977 non-null  int64
#  2   HADM_ID               31977 non-null  float64
#  3   SEQ_NUM               31977 non-null  float64
#  4   ICD9_CODE             31977 non-null  int64
#  5   CHARTTIME             19724 non-null  object
#  6   STORETIME             11947 non-null  object
#  7   CATEGORY              31977 non-null  object
#  8   CGID                  11947 non-null  float64
#  9   ISERROR               7 non-null      float64
#  10  TEXT                  31977 non-null  object
#  11  AGE                   31977 non-null  int64
#  12  ROW_ID                31977 non-null  int64
#  13  SUBJECT_ID            31977 non-null  int64
#  14  ADMITTIME             31977 non-null  object
# ...

# %%
df[df['AGE']>100]
# Out:
# Empty DataFrame
# Columns: [ROW_ID_x, SUBJECT_ID_x, HADM_ID, SEQ_NUM, ICD9_CODE, CHARTTIME, STORETIME, CATEGORY, CGID, ISERROR, TEXT, AGE, ROW_ID, SUBJECT_ID, ADMITTIME, DISCHTIME, DEATHTIME, ADMISSION_TYPE, ADMISSION_LOCATION, DISCHARGE_LOCATION, INSURANCE, LANGUAGE, RELIGION, MARITAL_STATUS, ETHNICITY, EDREGTIME, EDOUTTIME, DIAGNOSIS, HOSPITAL_EXPIRE_FLAG, HAS_CHARTEVENTS_DATA]
# Index: []

# %%
df[df['AGE']==0]
# Out:
#        ROW_ID_x  SUBJECT_ID_x   HADM_ID  SEQ_NUM  ICD9_CODE  \
# 1        341281         29799  165367.0      1.0      51881
# 3        339195         29631  141170.0      1.0      51881
# 5          8272           720  100753.0      1.0      51881
# 16       157919         14114  183312.0      1.0      51881
# 20       187471         16832  149054.0      1.0       5849
# ...         ...           ...       ...      ...        ...
# 31969    296675         26492  125102.0     31.0       4019
# 31970    603140         89565  178705.0     31.0      53081
# 31971    307987         27374  169788.0     31.0      53081
# 31972    278595         24955  154989.0     32.0      53081
# 31976    465900         58773  170349.0     39.0      53081
#
#                  CHARTTIME            STORETIME       CATEGORY     CGID  \
# 1      2200-08-05 15:44:00  2200-08-05 16:13:00  Nursing/other  20848.0
# 3      2180-12-06 02:46:00  2180-12-06 02:52:32        Nursing  14757.0
# ...

# %%
df[df['AGE']==0]['SUBJECT_ID'].nunique()
# Out:
# 12587

# %%
def correct_age(df1: pd.DataFrame) -> pd.DataFrame:
    
    #create copy 
    df = df1.copy()
    #Create look-up table of mean age based off of SUBJECT ID
    SUBJECT_ID_LOOKUP = df[df['AGE']!=0].groupby('SUBJECT_ID').mean()['AGE']
    
    #Replace values where AGE == 0. However note that some subjects only have AGE == 0 values
    for i in range(len(df)):
        if df['AGE'].iloc[i] == 0:
            try:
                df['AGE'].iloc[i] = SUBJECT_ID_LOOKUP.loc[df['SUBJECT_ID'].iloc[i]]
            except:
                continue
    return df

# %%
# df_corrected_sorted = correct_age(df_sorted)

# %%
# df_corrected_sorted[df_corrected_sorted['AGE']==0]

# %%
# df_corrected_sorted[df_corrected_sorted['AGE']==0]['SUBJECT_ID'].nunique()

# %%
df_corrected = correct_age(df)
# Out:
# /Applications/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
df_corrected
# Out:
#        ROW_ID_x  SUBJECT_ID_x   HADM_ID  SEQ_NUM  ICD9_CODE  \
# 0        269651         24136  153714.0      1.0       5849
# 1        341281         29799  165367.0      1.0      51881
# 2        484212         62854  129565.0      1.0      51881
# 3        339195         29631  141170.0      1.0      51881
# 4        157832         14106  184643.0      1.0       5849
# ...         ...           ...       ...      ...        ...
# 31972    278595         24955  154989.0     32.0      53081
# 31973    496889         65659  133827.0     32.0      53081
# 31974    504720         67348  179548.0     32.0       4019
# 31975    549697         77282  129551.0     36.0       4019
# 31976    465900         58773  170349.0     39.0      53081
#
#                  CHARTTIME            STORETIME           CATEGORY     CGID  \
# 0                      NaN                  NaN  Discharge summary      NaN
# 1      2200-08-05 15:44:00  2200-08-05 16:13:00      Nursing/other  20848.0
# ...

# %%
df_corrected[df_corrected['AGE']==0]
# Out:
#        ROW_ID_x  SUBJECT_ID_x   HADM_ID  SEQ_NUM  ICD9_CODE  \
# 1        341281         29799  165367.0      1.0      51881
# 3        339195         29631  141170.0      1.0      51881
# 5          8272           720  100753.0      1.0      51881
# 16       157919         14114  183312.0      1.0      51881
# 20       187471         16832  149054.0      1.0       5849
# ...         ...           ...       ...      ...        ...
# 31965    203928         18318  128140.0     30.0       4019
# 31969    296675         26492  125102.0     31.0       4019
# 31970    603140         89565  178705.0     31.0      53081
# 31972    278595         24955  154989.0     32.0      53081
# 31976    465900         58773  170349.0     39.0      53081
#
#                  CHARTTIME            STORETIME       CATEGORY     CGID  \
# 1      2200-08-05 15:44:00  2200-08-05 16:13:00  Nursing/other  20848.0
# 3      2180-12-06 02:46:00  2180-12-06 02:52:32        Nursing  14757.0
# ...

# %%
df_corrected[df_corrected['AGE']==0]['SUBJECT_ID'].nunique()
# Out:
# 10575

# %%
# df_sorted[df_sorted['AGE']==0]

# %%
# df_corrected_sorted

# %%
# print(df_corrected_sorted[df_corrected_sorted['AGE']==0].count())

# %%
# df_sorted[df_sorted['AGE']>100]

# %%
# df_sorted_final = df.merge(df_sorted, how='outer')
# df_sorted_final

# %%
# df_sorted_final['HADM_ID'].nunique()

# %%
# df_sorted_final[df_sorted_final['AGE']==0]

# %%
# df_sorted_final.sort_values('AGE')

# %%
# df_sorted_final = df_sorted_final.sort_values('AGE').drop_duplicates('HADM_ID', keep='first')
# df_sorted_final

# %%
#df.to_csv('mimic_all_ages', index=False)

# %% [markdown]
# ## Converting Remaining AGE=0 to Mean Value of AGE column {-}

# %%
df_corrected.info()
df_corrected.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31977 entries, 0 to 31976
# Data columns (total 30 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ROW_ID_x              31977 non-null  int64
#  1   SUBJECT_ID_x          31977 non-null  int64
#  2   HADM_ID               31977 non-null  float64
#  3   SEQ_NUM               31977 non-null  float64
#  4   ICD9_CODE             31977 non-null  int64
#  5   CHARTTIME             19724 non-null  object
#  6   STORETIME             11947 non-null  object
#  7   CATEGORY              31977 non-null  object
#  8   CGID                  11947 non-null  float64
#  9   ISERROR               7 non-null      float64
#  10  TEXT                  31977 non-null  object
#  11  AGE                   31977 non-null  float64
#  12  ROW_ID                31977 non-null  int64
#  13  SUBJECT_ID            31977 non-null  int64
#  14  ADMITTIME             31977 non-null  object
# ...

# %%
df_corrected[df_corrected['AGE']==0]
# Out:
#        ROW_ID_x  SUBJECT_ID_x   HADM_ID  SEQ_NUM  ICD9_CODE  \
# 1        341281         29799  165367.0      1.0      51881
# 3        339195         29631  141170.0      1.0      51881
# 5          8272           720  100753.0      1.0      51881
# 16       157919         14114  183312.0      1.0      51881
# 20       187471         16832  149054.0      1.0       5849
# ...         ...           ...       ...      ...        ...
# 31965    203928         18318  128140.0     30.0       4019
# 31969    296675         26492  125102.0     31.0       4019
# 31970    603140         89565  178705.0     31.0      53081
# 31972    278595         24955  154989.0     32.0      53081
# 31976    465900         58773  170349.0     39.0      53081
#
#                  CHARTTIME            STORETIME       CATEGORY     CGID  \
# 1      2200-08-05 15:44:00  2200-08-05 16:13:00  Nursing/other  20848.0
# 3      2180-12-06 02:46:00  2180-12-06 02:52:32        Nursing  14757.0
# ...

# %%
df_corrected[df_corrected['AGE']==0]['SUBJECT_ID'].nunique()
# Out:
# 10575

# %%
df_corrected_plot = sns.displot(df_corrected, x='AGE')
df_corrected_plot

# %%
df_corrected_plot.set(xlim=(20, 100))
df_corrected_plot

# %%
fig, ax = plt.subplots()
sns.distplot(df_corrected['AGE'], ax=ax)

ax.set_xlim(20, 100)
plt.show()
# Out:
# /Applications/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df_corrected
# Out:
#        ROW_ID_x  SUBJECT_ID_x   HADM_ID  SEQ_NUM  ICD9_CODE  \
# 0        269651         24136  153714.0      1.0       5849
# 1        341281         29799  165367.0      1.0      51881
# 2        484212         62854  129565.0      1.0      51881
# 3        339195         29631  141170.0      1.0      51881
# 4        157832         14106  184643.0      1.0       5849
# ...         ...           ...       ...      ...        ...
# 31972    278595         24955  154989.0     32.0      53081
# 31973    496889         65659  133827.0     32.0      53081
# 31974    504720         67348  179548.0     32.0       4019
# 31975    549697         77282  129551.0     36.0       4019
# 31976    465900         58773  170349.0     39.0      53081
#
#                  CHARTTIME            STORETIME           CATEGORY     CGID  \
# 0                      NaN                  NaN  Discharge summary      NaN
# 1      2200-08-05 15:44:00  2200-08-05 16:13:00      Nursing/other  20848.0
# ...

# %%
df_corrected_no_zeros = df_corrected[df_corrected['AGE']!=0]
df_corrected_no_zeros
# Out:
#        ROW_ID_x  SUBJECT_ID_x   HADM_ID  SEQ_NUM  ICD9_CODE  \
# 0        269651         24136  153714.0      1.0       5849
# 2        484212         62854  129565.0      1.0      51881
# 4        157832         14106  184643.0      1.0       5849
# 6        303720         27081  116846.0      1.0       5849
# 7        168250         15057  113790.0      1.0      51881
# ...         ...           ...       ...      ...        ...
# 31968    631425         95747  167336.0     30.0       4019
# 31971    307987         27374  169788.0     31.0      53081
# 31973    496889         65659  133827.0     32.0      53081
# 31974    504720         67348  179548.0     32.0       4019
# 31975    549697         77282  129551.0     36.0       4019
#
#                  CHARTTIME STORETIME           CATEGORY  CGID  ISERROR  \
# 0                      NaN       NaN  Discharge summary   NaN      NaN
# 2                      NaN       NaN  Discharge summary   NaN      NaN
# ...

# %%
## GETTING THE MEAN VALUE FOR AGE COLUMN WITHOUT ZEROS

df_mean = df_corrected_no_zeros['AGE'].mean()
print(df_mean)
# Out:
# 65.21533880697618

# %% [markdown]
# ### The MEAN value for AGE without 0 is 65.215 {-}

# %%
df_corrected[df_corrected['AGE']==0]
# Out:
#        ROW_ID_x  SUBJECT_ID_x   HADM_ID  SEQ_NUM  ICD9_CODE  \
# 1        341281         29799  165367.0      1.0      51881
# 3        339195         29631  141170.0      1.0      51881
# 5          8272           720  100753.0      1.0      51881
# 16       157919         14114  183312.0      1.0      51881
# 20       187471         16832  149054.0      1.0       5849
# ...         ...           ...       ...      ...        ...
# 31965    203928         18318  128140.0     30.0       4019
# 31969    296675         26492  125102.0     31.0       4019
# 31970    603140         89565  178705.0     31.0      53081
# 31972    278595         24955  154989.0     32.0      53081
# 31976    465900         58773  170349.0     39.0      53081
#
#                  CHARTTIME            STORETIME       CATEGORY     CGID  \
# 1      2200-08-05 15:44:00  2200-08-05 16:13:00  Nursing/other  20848.0
# 3      2180-12-06 02:46:00  2180-12-06 02:52:32        Nursing  14757.0
# ...

# %%
df_corrected['AGE'].replace(0, 65, inplace=True)

# %%
df_corrected
# Out:
#        ROW_ID_x  SUBJECT_ID_x   HADM_ID  SEQ_NUM  ICD9_CODE  \
# 0        269651         24136  153714.0      1.0       5849
# 1        341281         29799  165367.0      1.0      51881
# 2        484212         62854  129565.0      1.0      51881
# 3        339195         29631  141170.0      1.0      51881
# 4        157832         14106  184643.0      1.0       5849
# ...         ...           ...       ...      ...        ...
# 31972    278595         24955  154989.0     32.0      53081
# 31973    496889         65659  133827.0     32.0      53081
# 31974    504720         67348  179548.0     32.0       4019
# 31975    549697         77282  129551.0     36.0       4019
# 31976    465900         58773  170349.0     39.0      53081
#
#                  CHARTTIME            STORETIME           CATEGORY     CGID  \
# 0                      NaN                  NaN  Discharge summary      NaN
# 1      2200-08-05 15:44:00  2200-08-05 16:13:00      Nursing/other  20848.0
# ...

# %%
df_corrected[df_corrected['AGE']==0]
# Out:
# Empty DataFrame
# Columns: [ROW_ID_x, SUBJECT_ID_x, HADM_ID, SEQ_NUM, ICD9_CODE, CHARTTIME, STORETIME, CATEGORY, CGID, ISERROR, TEXT, AGE, ROW_ID, SUBJECT_ID, ADMITTIME, DISCHTIME, DEATHTIME, ADMISSION_TYPE, ADMISSION_LOCATION, DISCHARGE_LOCATION, INSURANCE, LANGUAGE, RELIGION, MARITAL_STATUS, ETHNICITY, EDREGTIME, EDOUTTIME, DIAGNOSIS, HOSPITAL_EXPIRE_FLAG, HAS_CHARTEVENTS_DATA]
# Index: []

# %%
fig, ax = plt.subplots()
sns.distplot(df_corrected['AGE'], ax=ax)

ax.set_xlim(20, 100)
plt.show()
# Out:
# /Applications/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## Remove Columns and AGE=0 {-}

# %%
mimic_text_labels_merged_cleaned = df_corrected.drop(columns=['ROW_ID_x', 'SUBJECT_ID_x', 'CHARTTIME', 'STORETIME', 'CGID', 'ISERROR',
                                          'ADMITTIME', 'DISCHTIME', 'DEATHTIME', 'ADMISSION_LOCATION', 'DISCHARGE_LOCATION',
                                                   'INSURANCE', 'LANGUAGE', 'RELIGION', 'MARITAL_STATUS', 'ETHNICITY',
                                                   'EDREGTIME', 'EDOUTTIME', 'DIAGNOSIS', 'HOSPITAL_EXPIRE_FLAG',
                                                   'HAS_CHARTEVENTS_DATA'])
mimic_text_labels_merged_cleaned
# Out:
#         HADM_ID  SEQ_NUM  ICD9_CODE           CATEGORY  \
# 0      153714.0      1.0       5849  Discharge summary
# 1      165367.0      1.0      51881      Nursing/other
# 2      129565.0      1.0      51881  Discharge summary
# 3      141170.0      1.0      51881            Nursing
# 4      184643.0      1.0       5849  Discharge summary
# ...         ...      ...        ...                ...
# 31972  154989.0     32.0      53081      Nursing/other
# 31973  133827.0     32.0      53081          Radiology
# 31974  179548.0     32.0       4019  Discharge summary
# 31975  129551.0     36.0       4019          Radiology
# 31976  170349.0     39.0      53081                ECG
#
#                                                     TEXT   AGE  ROW_ID  \
# 0      Admission Date: [**2159-7-6**]        Discharg...  51.0   29492
# 1      FOCUS; NURISNG PROGRESS NOTE\n(Continued)\nSPL...  65.0   36317
# 2      Admission Date:  [**2146-6-1**]              D...  79.0   47150
# ...

# %%
mimic_text_labels_merged_cleaned.AGE = mimic_text_labels_merged_cleaned.AGE.astype(int)
mimic_text_labels_merged_cleaned
# Out:
#         HADM_ID  SEQ_NUM  ICD9_CODE           CATEGORY  \
# 0      153714.0      1.0       5849  Discharge summary
# 1      165367.0      1.0      51881      Nursing/other
# 2      129565.0      1.0      51881  Discharge summary
# 3      141170.0      1.0      51881            Nursing
# 4      184643.0      1.0       5849  Discharge summary
# ...         ...      ...        ...                ...
# 31972  154989.0     32.0      53081      Nursing/other
# 31973  133827.0     32.0      53081          Radiology
# 31974  179548.0     32.0       4019  Discharge summary
# 31975  129551.0     36.0       4019          Radiology
# 31976  170349.0     39.0      53081                ECG
#
#                                                     TEXT  AGE  ROW_ID  \
# 0      Admission Date: [**2159-7-6**]        Discharg...   51   29492
# 1      FOCUS; NURISNG PROGRESS NOTE\n(Continued)\nSPL...   65   36317
# 2      Admission Date:  [**2146-6-1**]              D...   79   47150
# ...

# %%
(mimic_text_labels_merged_cleaned['AGE']==0).sum()
# Out:
# 0

# %%
mimic_text_labels_merged_cleaned['AGE'].value_counts()
# Out:
# 65    11982
# 66      538
# 84      531
# 78      523
# 80      520
#       ...
# 92        2
# 93        2
# 95        2
# 11        1
# 91        1
# Name: AGE, Length: 93, dtype: int64

# %%
mimic_text_labels_merged_cleaned.to_csv('mimic_text_labels_merged_cleaned_no_zeros.csv', index=False)

# %%
data_test = pd.read_csv('mimic_text_labels_merged_cleaned_no_zeros.csv')
data_test
# Out:
#         HADM_ID  SEQ_NUM  ICD9_CODE           CATEGORY  \
# 0      153714.0      1.0       5849  Discharge summary
# 1      165367.0      1.0      51881      Nursing/other
# 2      129565.0      1.0      51881  Discharge summary
# 3      141170.0      1.0      51881            Nursing
# 4      184643.0      1.0       5849  Discharge summary
# ...         ...      ...        ...                ...
# 31972  154989.0     32.0      53081      Nursing/other
# 31973  133827.0     32.0      53081          Radiology
# 31974  179548.0     32.0       4019  Discharge summary
# 31975  129551.0     36.0       4019          Radiology
# 31976  170349.0     39.0      53081                ECG
#
#                                                     TEXT  AGE  ROW_ID  \
# 0      Admission Date: [**2159-7-6**]        Discharg...   51   29492
# 1      FOCUS; NURISNG PROGRESS NOTE\n(Continued)\nSPL...   65   36317
# 2      Admission Date:  [**2146-6-1**]              D...   79   47150
# ...

# %%
(data_test['AGE']==0).sum()
# Out:
# 0

# %%
# mimic_text_labels_age_0 = mimic_text_labels_merged_cleaned[mimic_text_labels_merged_cleaned['AGE'] == 0]
# mimic_text_labels_age_0

# %%
#mimic_text_labels_age_0.to_csv('mimic_age_equal_0.csv', index=False)

# %%
#df_x = pd.read_csv('mimic_age_equal_0.csv')

# %%
#df_x

# %% [markdown]
# #### Exploring AGE=0 {-}

# %%
# mimic_text_labels_age_0_section_1 = mimic_text_labels_age_0.sample(frac=0.25)
# mimic_text_labels_age_0_section_1

# %%
# mimic_text_labels_age_0_section_2 = mimic_text_labels_age_0.sample(frac=0.25)
# mimic_text_labels_age_0_section_2

# %%
#mimic_text_labels_age_0_section_2.to_csv('mimic_text_labels_age_0_section_2.csv', index=False)

# %%
#mimic_text_labels_age_0_section_1.to_csv('mimic_text_labels_age_0_section_1.csv', index=False)

# %%
# mimic_sample_1 = pd.read_csv('mimic_text_labels_age_0_section_1.csv')
# mimic_sample_1.info()

# %%
# mimic_sample_2 = pd.read_csv('mimic_text_labels_age_0_section_2.csv')
# mimic_sample_2.info()

# %% [markdown]
# #### Exploring AGE=0 {-}

# %%
# mimic_sample_1

# %%
# print(mimic_sample_1.TEXT[999])

# %% [markdown]
# #### Removing AGE=0 {-}

# %%
# # removing AGE=0
# mimic_text_labels_merged_cleaned_df = mimic_text_labels_merged_cleaned.loc[mimic_text_labels_merged_cleaned.AGE != 0].copy()
# mimic_text_labels_merged_cleaned_df

# %%
# mimic_text_labels_merged_cleaned_df.info()

# %%
#mimic_text_labels_merged_cleaned_df.to_csv('mimic_text_labels_merged_cleaned_df.csv', index=False)

# %%
# mimic_text_labels_merged_cleaned_df.to_csv('mimic_age_not_equal_0.csv', index=False)

# %%
# df_y = pd.read_csv('mimic_age_not_equal_0.csv')
# df_y

# %%
# print(df_y.TEXT[111])

# %% [markdown]
# ## Comparing Counts of Average Words for both AGE=0 and AGE!=0 {-}

# %%
df_x

# %%
df_x['totalwords'] = df_x['TEXT'].str.split().str.len()

# %%
df_x

# %%
df_y

# %%
df_y['totalwords'] = df_y['TEXT'].str.split().str.len()

# %%
df_x

# %%
df_y

# %%
df_x.info()
df_y.info()

# %%
mimic_age_not_equal_0 = df_y
mimic_age_not_equal_0

# %%
mimic_age_not_equal_0.info()

# %%
mimic_age_equal_0 = df_x
mimic_age_equal_0

# %%
mimic_age_equal_0.info()

# %%
mimic_age_not_equal_0_word_sum = mimic_age_not_equal_0['totalwords'].sum()
print(mimic_age_not_equal_0_word_sum)

# %%
mimic_age_equal_0_word_sum = mimic_age_equal_0['totalwords'].sum()
print(mimic_age_equal_0_word_sum)

# %%
print(mimic_age_not_equal_0_word_sum / mimic_age_equal_0_word_sum)

# %% [markdown]
# <b>We can see here that AGE!=0 has approx. 5 times the word count that AGE=0 has even though there is only a difference of 3447 rows (AGE!=0 has 17712 rows and AGE=0 has 14265 rows). </b>
